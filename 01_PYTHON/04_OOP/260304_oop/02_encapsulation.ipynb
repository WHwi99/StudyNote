# %% [markdown]
# # 캡술화
#  - private 속성(변수)을 선언해서 외부에서 직접 접근을 막고, 제공 된 메소드를 통해서 사용하도록 강제한다.
#  - 주요한 데이터가 외부에 노출 되지 않는 은닉화 효과를 얻을 수 있다.

# %%
class Account:
    def __init__(self, username, balance):
        # private 접근 제한 처리
        self.__username = username
        self.__balance = balance
        
    def deposit(self, money):
        """
        입금 메소드
        - money 유효성 검사
        - 오염 된 입금 처리 방지
        """
        if money <= 0:
            print("입금액이 유효하지 않습니다.")
        else:
            self.__balance += money
            print("입금이 정상처리 되었습니다.")
            
    def withdraw(self, money):
        if money <= 0:
            print("출금액이 유효하지 않습니다.")
        elif money > self.__balance:
            print("잔액이 부족합니다.")
        else:
            self.__balance -= money
            print("츨금이 정상처리 되었습니다.")
            
    def info(self):
        print(f"{self.__username}님의 계좌의 현재 잔액은 {self.__balance}원 입니다.")

# %%
# 파이썬에서 private는 약속이다
# _클래스명__변수명으로 이름이 바뀐 것 이므로 접근하려고 하면 접근 가능하지만 개발자 사이의 약속으로 외부 접근 X    
acc = Account('hong', 1_000_000)
# print(acc.username)
# print(acc.balance)

# 권장하지 않는 방법 => 꺼내올수는 있지만 개발자 사이의 약속이기에 접근하지 않도록 한다.
print(acc._Account__balance)
print(acc._Account__username)
# Out:
# 1000000
# hong

# %% [markdown]
# ## 왜 캡술화를 할까?
#  - acc.balance -= 1억 처럼 직접 값을 수정할 수 있다면 은행 프로그램은 망가지게 된다.
#  - deposit(), withdraw()와 같이 메소드라는 필터를 거쳐서 잘못 된 데이터가 객체 안으로 들어오는 것을 막는 것이 캡슐화의 핵심이다.

# %%
# 입금하기
acc.deposit(500_000)
acc.deposit(-500_000)
acc.info()

# 출금하기
acc.withdraw(700_000)
acc.withdraw(-700_000)
acc.withdraw(40_000_000)
acc.info()
# Out:
# 입금이 정상처리 되었습니다.
# 입금액이 유효하지 않습니다.
# hong님의 계좌의 현재 잔액은 1500000원 입니다.
# 츨금이 정상처리 되었습니다.
# 출금액이 유효하지 않습니다.
# 잔액이 부족합니다.
# hong님의 계좌의 현재 잔액은 800000원 입니다.
