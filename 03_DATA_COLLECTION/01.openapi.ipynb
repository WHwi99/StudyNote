# %% [markdown]
# # OpenAPI를 이용한 데이터 수집
#
# ## API(Application Programming Interface)
#  - 프로그램과 프로그램이 서로 데이터를 주고 받기 위한 **규칙**
#
# ## OpenAPI
#  - 외부 개발자가 사용할 수 있도록 공개된 API
#  - HTTP 기반 요청
#  - JSON or XML 형태의 응답
#  - API Key 필요(서버측 요청량 조절)

# %% [markdown]
# ## 환경변수 관리
# - 어플리케이션의 Client ID, Client Secret 값은 절대 외부에 노출 되어서는 안된다.
# - dotenv를 통해 관리할 수 있다.

# %%
# 셀 매직 명령어(%)로 python-dotenv 설치
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in c:\Users\test\miniforge3\envs\pystudy_env\Lib\site-packages (1.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# .env의 내용을 읽어서 환경 변수로 등록 처리
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# 환경 변수로 등록 된 클라이언트 아이디와 시크릿 키를 읽어서 변수에 저장
import os

NAVER_CLIENT_ID = os.getenv('NAVER_CLIENT_ID')
NAVER_CLIENT_SECRET = os.getenv('NAVER_CLIENT_SECRET')

# %%
# 네이버 검색 예제
import os
import sys
import urllib.request
client_id = NAVER_CLIENT_ID
client_secret = NAVER_CLIENT_SECRET
encText = urllib.parse.quote("인공지능")
url = "https://openapi.naver.com/v1/search/news?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Fri, 13 Mar 2026 09:58:09 +0900",
# 	"total":3767095,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"한전, 조폐공사와 AI 기반 감사역량 제고 맞손",
# 			"originallink":"https:\/\/news.tf.co.kr\/read\/economy\/2301789.htm",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/629\/0000481009?sid=101",
# 			"description":"후속 실무회의…협력과제 지속 발굴 한국전력이 <b>인공지능<\/b>(AI)을 활용한 감사 전문성 강화에 나섰다. 한전은 한국조폐공사와 감사 전문성 제고와 내부통제 강화를 위한 업무협약(MOU)을 지난 12일 체결했다. 이번 MOU에... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:57:00 +0900"
# 		},
# 		{
# 			"title":"성남시 ‘드론 실증도시 구축사업’ 전국 최초 6년 연속 선정",
# 			"originallink":"https:\/\/gg.newdaily.co.kr\/site\/data\/html\/2026\/03\/13\/2026031300094.html",
# 			"link":"https:\/\/gg.newdaily.co.kr\/site\/data\/html\/2026\/03\/13\/2026031300094.html",
# 			"description":"앞서 시는 2025년도 드론 실증도시 사업에서 <b>인공지능<\/b>(AI) 기반 도로 위험요소 탐지 서비스와 드론 3차원 모델 기반 폐쇄회로 텔레비전(CCTV) 설치 위치 분석 서비스를 성공적으로 운영하며 전국 지자체 가운데 가장 폭넓은... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"“AI가 수면을 설계한다” 경동나비엔, 판교서 스마트 숙면 체험",
# 			"originallink":"http:\/\/digitalchosun.dizzo.com\/site\/data\/html_dir\/2026\/03\/13\/2026031380038.html",
# 			"link":"http:\/\/digitalchosun.dizzo.com\/site\/data\/html_dir\/2026\/03\/13\/2026031380038.html",
# 			"description":"김경희 기자 | <b>인공지능<\/b>(AI)과 사물인터넷(IoT)을 활용해 수면 환경을 관리하는 슬립테크(Sleep Tech) 시장이 확대되는 가운데 관련 기술을 직접 체험할 수 있는 행사가 열린다. 경동나비엔은 세계 수면의 날(3월 13일)을... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"[진주소식]농산물 가공 창업 설명회 개최 등",
# 			"originallink":"https:\/\/www.newsis.com\/view\/NISX20260313_0003546848",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/003\/0013819792?sid=102",
# 			"description":"이날 교육을 맡은 변세광 한국식품산업클러스터진흥원 창업교육부 차장은 ▲농산물 가공 창업의 유형과 절차 ▲식품산업 및 창업 동향 분석 ▲<b>인공지능<\/b>(AI)을 활용한 사업계획서 작성 및 실무 등 창업 단계에 필요한... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"JKM, '세종 캠퍼스' 준공…&quot;AI 반도체 초격차 공급망 완성&quot;",
# 			"originallink":"https:\/\/www.mt.co.kr\/stock\/2026\/03\/13\/2026031308193643299",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/008\/0005329491?sid=101",
# 			"description":"이번 세종 캠퍼스 준공은 생성형 AI(<b>인공지능<\/b>) 확산에 따른 반도체 수요 증가에 대응하고 고성능 소재의 안정적 공급과 현지화 기술 지원 체계를 강화하기 위한 전략적 행보다. 최근 생성형 AI 산업 확대로 AI 학습용... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"금호석유화학 휴그린 &quot;환기 걱정 끝&quot;…신민아 배우와 '살아보고서' 캠페...",
# 			"originallink":"http:\/\/www.newsian.co.kr\/news\/articleView.html?idxno=87173",
# 			"link":"http:\/\/www.newsian.co.kr\/news\/articleView.html?idxno=87173",
# 			"description":"이 제품은 <b>인공지능<\/b>(AI) 스마트센서가 실내 공기를 스스로 분석해, 굳이 창문을 열지 않아도 알아서 공기를 깨끗하게 관리하는 것으로 전해진다. 두 번째 '엄마를 부탁해' 편은 신민아가 어머니에게 창호를 선물하는... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"방산과 게임의 만남…한화에어로, 크래프톤과 '피지컬 AI' 공동개발",
# 			"originallink":"https:\/\/news.einfomax.co.kr\/news\/articleView.html?idxno=4403513",
# 			"link":"https:\/\/news.einfomax.co.kr\/news\/articleView.html?idxno=4403513",
# 			"description":"한화에어로스페이스[012450]는 크래프톤[259960]과 '피지컬 AI(<b>인공지능<\/b>)' 공동 개발에 나선다고 13일 밝혔다. 이를 위해 한화에어로스페이스는 크래프톤과 'AI 기술 공동 개발과 합작법인(JV) 설립 등을 위한 업무협약(MOU)... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"LS, 지난해 영업이익 1조5000억…출범 이후 최대 실적",
# 			"originallink":"https:\/\/www.pinpointnews.co.kr\/news\/articleView.html?idxno=436432",
# 			"link":"https:\/\/www.pinpointnews.co.kr\/news\/articleView.html?idxno=436432",
# 			"description":"<b>인공지능<\/b>(AI) 확산에 따른 전력 인프라 투자 확대가 이어지면서 전선·전력기기 계열사의 실적이 크게 늘어난 영향이다. LS는 지난해 매출 45조7,223억 원, 영업이익 1조4,884억 원을 기록했다고 12일 밝혔다. 2003년 그룹... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"[AI는 지금] 할리우드 흔든 AI…제작 혁신 속 '노동 갈등' 확산",
# 			"originallink":"https:\/\/zdnet.co.kr\/view\/?no=20260313095348",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/092\/0002414204?sid=105",
# 			"description":"할리우드 영화 산업에서 <b>인공지능<\/b>(AI) 기술 확보 경쟁이 본격화되고 있다. 스트리밍 플랫폼과 영화 스튜디오들이 제작 효율성을 높이기 위해 AI 스타트업 인수와 기술 도입을 확대하면서 영화 제작 환경에도 변화가... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		},
# 		{
# 			"title":"AI發 메모리 급등에 전쟁까지…스마트폰 수익성 '경고등'",
# 			"originallink":"https:\/\/www.ebn.co.kr\/news\/articleView.html?idxno=1702294",
# 			"link":"https:\/\/www.ebn.co.kr\/news\/articleView.html?idxno=1702294",
# 			"description":"<b>인공지능<\/b>(AI) 수요로 촉발된 메모리 가격 급등에 중동 전쟁까지 겹치면서 스마트폰 업체들의 수익성에 경고등이 켜졌다. 원가 부담 확대, 전쟁 리스크, 공급망 불안 등이 동시에 작용할 경우 스마트폰 시장 전반의... ",
# 			"pubDate":"Fri, 13 Mar 2026 09:56:00 +0900"
# 		}
# 	]
# }

# %%
## request 모듈을 사용한 요청으로 변경
# %pip install requests
# Out:
# Requirement already satisfied: requests in c:\Users\test\miniforge3\envs\pystudy_env\Lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\test\miniforge3\envs\pystudy_env\Lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\test\miniforge3\envs\pystudy_env\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\test\miniforge3\envs\pystudy_env\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\test\miniforge3\envs\pystudy_env\Lib\site-packages (from requests) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
#  request 모듈
import requests
import csv

url = 'https://openapi.naver.com/v1/search/news.json'

headers = {
    "X-Naver-Client-Id" : NAVER_CLIENT_ID,
    "X-Naver-Client-Secret" : NAVER_CLIENT_SECRET
}

# query string
params = {
    'query' : '인공지능',
    'display' : 10,         # 10~100
    'start' : 1,
    'sort' : 'sim'          # sim or date
}

# 요청
response = requests.get(url, headers=headers, params=params)
print(f"HTTP Status Code : {response.status_code}")


# 결과 출력
if response.status_code == 200:
    # print(response.text)
    # response 객체는 json 문자열 형태로 응답이 돌아왔으므로 json() 메소드를 통해 dict로 변환
    data = response.json()
    print(data)
    
    #csv 파일로 저장하기
    with open('naver_news_인공지능.csv','w',encoding = 'utf-8',newline='') as f:
        # items 리스트의 첫번째 요소의 키를 필드명으로 사용
        fieldnames = list(data['items'][0].keys())
        print(fieldnames)
        # csv 파일에 저장할 필드명 정의
        writer = csv.DictWriter(f, fieldnames=fieldnames)
        writer.writeheader()                # 헤더 작성
        writer.writerows(data['items'])     # 데이터 작성
else:
    print(f"Error Code : {response.status_code}")
# Out:
# HTTP Status Code : 200
# {'lastBuildDate': 'Fri, 13 Mar 2026 10:24:52 +0900', 'total': 3767265, 'start': 1, 'display': 10, 'items': [{'title': '과기정통·산업·중기부, 4320억 규모 AI전환 사업 통합 공고', 'originallink': 'https://www.newsis.com/view/NISX20260312_0003545057', 'link': 'https://n.news.naver.com/mnews/article/003/0013817590?sid=105', 'description': '과학기술정보통신부, 산업통상자원부, 중소벤처기업부가 산업 <b>인공지능</b>(AI) 전문기업과 제조기업의 AI전환(AX) 사업 참여 환경 개선을 위해 공동 대응한다. 과기정통부와 산업부, 중기부는 올해 주요 AX 사업을 통합... ', 'pubDate': 'Thu, 12 Mar 2026 12:00:00 +0900'}, {'title': '이재명 대통령 “약속은 지킵니다”…‘국민주권정부’ 성과 알리기 나...', 'originallink': 'https://www.mk.co.kr/article/11987118', 'link': 'https://n.news.naver.com/mnews/article/009/0005649646?sid=100', 'description': '이 대통령은 과학기술정보통신부·산업통상자원부·중소벤처기업부가 4230억원대 <b>인공지능</b>(AI) 전환 사업 통합을 공고했다는 소식도 알렸다. 3개 부처는 주요 AI 전환 사업을 통합 공고하고 기업 대상 설명회를 개최할... ', 'pubDate': 'Fri, 13 Mar 2026 08:55:00 +0900'}, {'title': "AI 공포에 주가 40% 폭락…'18년 경력' CEO 물러난다", 'originallink': 'https://www.hankyung.com/article/202603138163i', 'link': 'https://n.news.naver.com/mnews/article/015/0005261889?sid=105', 'description': "테크 전문매체 디인포메이션은 “<b>인공지능</b>(AI)의 위협에 대응하기 위해 소프트웨어 기업이 경영진 개편에 나선 상징적인 사례”라고 분석했다. 'AI 공포'에 주가 40% 하락 나라옌 CEO는 12일(현지시간) “향후... ", 'pubDate': 'Fri, 13 Mar 2026 09:42:00 +0900'}, {'title': '한국서부발전, <b>인공지능</b> 활용 5명 체인지메이커 시상', 'originallink': 'http://www.fnnews.com/news/202603121624101321', 'link': 'https://n.news.naver.com/mnews/article/014/0005490589?sid=101', 'description': '특히 올해 시상식에서는 <b>인공지능</b>(AI) 기술을 기반으로 사회문제 해결에 나선 혁신 사례들이 다수 선정됐다. 디지털 재활 솔루션, 사고 자동 신고 시스템, 급식 복지 플랫폼 등 다양한 분야에서 기술 기반 사회혁신 모델이... ', 'pubDate': 'Thu, 12 Mar 2026 16:26:00 +0900'}, {'title': '과기정통부,‘<b>인공지능</b> 윤리원칙’ 제정 착수', 'originallink': 'https://www.dailian.co.kr/news/view/1620242/?sc=Naver', 'link': 'https://n.news.naver.com/mnews/article/119/0003068672?sid=105', 'description': '과학기술정보통신부는 13일 인스파이어 비즈센터 서울에서 ‘<b>인공지능</b> 윤리원칙’과 관련해 전문가 자문단을 발족했다. AI 윤리원칙은 AI가 사회에 미칠 수 있는 긍정적·부정적 영향을 고려해 인간 중심적이고 책임있는... ', 'pubDate': 'Fri, 13 Mar 2026 10:02:00 +0900'}, {'title': "'<b>인공지능</b> 윤리원칙' 제정에 속도 낸다... &quot;인간중심 AI개발·활용 촉진...", 'originallink': 'https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003214551&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news', 'link': 'https://n.news.naver.com/mnews/article/047/0002507918?sid=101', 'description': "▲  안전하고 신뢰할 수있는 <b>인공지능</b>(AI) 사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정 ⓒ omilaev on Unsplash 정부가 안전하고 신뢰할 수 있는 <b>인공지능</b>(AI)사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정에 본격 착수한다. AI가... ", 'pubDate': 'Fri, 13 Mar 2026 10:11:00 +0900'}, {'title': '원주, 의료 <b>인공지능</b>·반도체 발전 방안 모색', 'originallink': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=8507431&ref=A', 'link': 'https://n.news.naver.com/mnews/article/056/0012141206?sid=101', 'description': '원주시는 어제(12일), 원주미래산업진흥원에서 의료 <b>인공지능</b>과 반도체 산업 육성을 위한 토론회를 개최했습니다. 이 자리에선 의료 분야 <b>인공지능</b>과 반도체 기술 확산 상황을 공유하고, 원주의 첨단 산업 육성 전략을... ', 'pubDate': 'Fri, 13 Mar 2026 08:33:00 +0900'}, {'title': "광주시, 경기도 최초 '<b>인공지능</b> 모자이크 CCTV' 민원실 도입", 'originallink': 'https://news.tf.co.kr/read/national/2301394.htm', 'link': 'https://n.news.naver.com/mnews/article/629/0000480612?sid=102', 'description': "경기 광주시는 민원실 내 안전 확보와 개인정보 보호 강화를 위해 경기도 민원실 가운데 최초로 '<b>인공지능</b>(AI) 모자이크 CC(폐쇄회로)TV'를 도입했다고 12일 밝혔다. 이번에 도입된 AI 모자이크 CCTV는 민원실 내 촬영... ", 'pubDate': 'Thu, 12 Mar 2026 11:16:00 +0900'}, {'title': "정부, '<b>인공지능</b> 고속도로 구축' 본격화…2조800억 투자", 'originallink': 'https://www.etoday.co.kr/news/view/2564810', 'link': 'https://www.etoday.co.kr/news/view/2564810', 'description': '이투데이=김연진 기자 | 과학기술정보통신부는 대한민국의 <b>인공지능</b>(AI) 생태계를 활성화하고 AI 3대 강국으로 도약하기 위한 핵심 인프라인 ‘AI 고속도로 구축’을 본격 추진한다고 12일 밝혔다. 이를 위해, 4월... ', 'pubDate': 'Thu, 12 Mar 2026 16:36:00 +0900'}, {'title': '청주대 조경학과, <b>인공지능</b> 접목 교육모델 도입', 'originallink': 'http://www.inews24.com/view/1948312', 'link': 'https://n.news.naver.com/mnews/article/031/0001012834?sid=102', 'description': '청주대학교(총장 김윤배)는 조경학과가 <b>인공지능</b>(AI)을 전공 교육에 접목한 교육 혁신 모델 ‘AI Triple Track’을 도입했 ...
# ['title', 'originallink', 'link', 'description', 'pubDate']

# %% [markdown]
# ## json 데이터 형식을 xml 데이터 형식 응답으로 변경

# %%
import requests

url = 'https://openapi.naver.com/v1/search/news.xml'

headers = {
    "X-Naver-Client-Id" : NAVER_CLIENT_ID,
    "X-Naver-Client-Secret" : NAVER_CLIENT_SECRET
}

# query string
params = {
    'query' : '인공지능',
    'display' : 10,         # 10~100
    'start' : 1,
    'sort' : 'sim'          # sim or date
}

# 요청
response = requests.get(url, headers=headers, params=params)
print(f"HTTP Status Code : {response.status_code}")


# 결과 출력
if response.status_code == 200:
    print(response.text)
    
    # XML 파일로 저장 - response.content는 bytes 타입이므로 바이너리 모드로 파일을 열어서 저장한다.
    with open('naver_news_인공지능.xml','wb') as f:
        f.write(response.content)
  
else:
    print(f"Error Code : {response.status_code}")
# Out:
# HTTP Status Code : 200
# <?xml version="1.0" encoding="UTF-8"?><rss version="2.0"><channel><title>Naver Open API - news ::&apos;인공지능&apos;</title><link>https://search.naver.com</link><description>Naver Search Result</description><lastBuildDate>Fri, 13 Mar 2026 10:46:31 +0900</lastBuildDate><total>3767396</total><start>1</start><display>10</display><item><title>네이버클라우드·코난테크놀로지, 국방·제조 특화 AI 협력</title><originallink>https://www.newsis.com/view/NISX20260313_0003546987</originallink><link>https://n.news.naver.com/mnews/article/003/0013819966?sid=105</link><description>네이버클라우드가 &lt;b&gt;인공지능&lt;/b&gt;(AI) 소프트웨어 전문기업 코난테크놀로지와 ‘국방·제조 특화 LLM 및 피지컬 AI 협력’을 위한 업무협약(MOU)을 체결하고, 이를 위한 생성형 AI 생태계 확장에 나선다고 13일 밝혔다. 이번... </description><pubDate>Fri, 13 Mar 2026 10:41:00 +0900</pubDate></item><item><title>이재명 대통령 “약속은 지킵니다”…‘국민주권정부’ 성과 알리기 나...</title><originallink>https://www.mk.co.kr/article/11987118</originallink><link>https://n.news.naver.com/mnews/article/009/0005649646?sid=100</link><description>이 대통령은 과학기술정보통신부·산업통상자원부·중소벤처기업부가 4230억원대 &lt;b&gt;인공지능&lt;/b&gt;(AI) 전환 사업 통합을 공고했다는 소식도 알렸다. 3개 부처는 주요 AI 전환 사업을 통합 공고하고 기업 대상 설명회를 개최할... </description><pubDate>Fri, 13 Mar 2026 08:55:00 +0900</pubDate></item><item><title>AI 공포에 주가 40% 폭락…&apos;18년 경력&apos; CEO 물러난다</title><originallink>https://www.hankyung.com/article/202603138163i</originallink><link>https://n.news.naver.com/mnews/article/015/0005261889?sid=105</link><description>테크 전문매체 디인포메이션은 “&lt;b&gt;인공지능&lt;/b&gt;(AI)의 위협에 대응하기 위해 소프트웨어 기업이 경영진 개편에 나선 상징적인 사례”라고 분석했다. &apos;AI 공포&apos;에 주가 40% 하락 나라옌 CEO는 12일(현지시간) “향후... </description><pubDate>Fri, 13 Mar 2026 09:42:00 +0900</pubDate></item><item><title>한국서부발전, &lt;b&gt;인공지능&lt;/b&gt; 활용 5명 체인지메이커 시상</title><originallink>http://www.fnnews.com/news/202603121624101321</originallink><link>https://n.news.naver.com/mnews/article/014/0005490589?sid=101</link><description>특히 올해 시상식에서는 &lt;b&gt;인공지능&lt;/b&gt;(AI) 기술을 기반으로 사회문제 해결에 나선 혁신 사례들이 다수 선정됐다. 디지털 재활 솔루션, 사고 자동 신고 시스템, 급식 복지 플랫폼 등 다양한 분야에서 기술 기반 사회혁신 모델이... </description><pubDate>Thu, 12 Mar 2026 16:26:00 +0900</pubDate></item><item><title>과기정통부,‘&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙’ 제정 착수</title><originallink>https://www.dailian.co.kr/news/view/1620242/?sc=Naver</originallink><link>https://n.news.naver.com/mnews/article/119/0003068672?sid=105</link><description>과학기술정보통신부는 13일 인스파이어 비즈센터 서울에서 ‘&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙’과 관련해 전문가 자문단을 발족했다. AI 윤리원칙은 AI가 사회에 미칠 수 있는 긍정적·부정적 영향을 고려해 인간 중심적이고 책임있는... </description><pubDate>Fri, 13 Mar 2026 10:02:00 +0900</pubDate></item><item><title>&apos;&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙&apos; 제정에 속도 낸다... &amp;quot;인간중심 AI개발·활용 촉진...</title><originallink>https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003214551&amp;CMPT_CD=P0010&amp;utm_source=naver&amp;utm_medium=newsearch&amp;utm_campaign=naver_news</originallink><link>https://n.news.naver.com/mnews/article/047/0002507918?sid=101</link><description>▲  안전하고 신뢰할 수있는 &lt;b&gt;인공지능&lt;/b&gt;(AI) 사회 구현을 위한 &apos;&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙&apos; 제정 ⓒ omilaev on Unsplash 정부가 안전하고 신뢰할 수 있는 &lt;b&gt;인공지능&lt;/b&gt;(AI)사회 구현을 위한 &apos;&lt;b&gt;인공지능&lt;/b&gt; 윤리원칙&apos; 제정에 본격 착수한다. AI가... </description><pubDate>Fri, 13 Mar 2026 10:11:00 +0900</pubDate></item><item><title>광주시, 경기도 최초 &apos;&lt;b&gt;인공지능&lt;/b&gt; 모자이크 CCTV&apos; 민원실 도입</title><originallink>https://news.tf.co.kr/read/national/2301394.htm</originallink><link>https://n.news.naver.com/mnews/article/629/0000480612?sid=102</link><description>경기 광주시는 민원실 내 안전 확보와 개인정보 보호 강화를 위해 경기도 민원실 가운데 최초로 &apos;&lt;b&gt;인공지능&lt;/b&gt;(AI) 모자이크 CC(폐쇄회로)TV&apos;를 도입했다고 12일 밝혔다. 이번에 도입된 AI 모자이크 CCTV는 민원실 내 촬영... </description><pubDate>Thu, 12 Mar 2026 11:16:00 +0900</pubDate></item><item><title>정부, &apos;&lt;b&gt;인공지능&lt;/b&gt; 고속도로 구축&apos; 본격화…2조800억 투자</title><originallink>https://www.etoday.co.kr/news/view/2564810</originallink><link>https://www.etoday.co.kr/news/view/2564810</link><description>이투데이=김연진 기자 | 과학기술정보통신부는 대한민국의 &lt;b&gt;인공지능&lt;/b&gt;(AI) 생태계를 활성화하고 AI 3대 강국으로 도약하기 위한 핵심 인프 ...

# %% [markdown]
# ## 데이터 DB 저장하기
#
# ### 테이블/모델 설계

# %%
from dataclasses import dataclass
from datetime import datetime
from typing import Optional

@dataclass
class NaverNews:
    
    id : int
    title : str
    originallink : str
    link : str
    description : str
    pubDate : str
    create_at : Optional[datetime] = None

# %% [markdown]
# ## OpenAPI로 수집 된 데이터 DB 저장하기

# %%
import requests

url = 'https://openapi.naver.com/v1/search/news.json'

headers = {
    "X-Naver-Client-Id" : NAVER_CLIENT_ID,
    "X-Naver-Client-Secret" : NAVER_CLIENT_SECRET
}

# query string
params = {
    'query' : '인공지능',
    'display' : 10,         # 10~100
    'start' : 1,
    'sort' : 'sim'          # sim or date
}

# 요청
response = requests.get(url, headers=headers, params=params)
naver_news_list: list[NaverNews] = []

# 결과 출력
if response.status_code == 200:
    data = response.json()  # dict로 변환
    items = data['items']
    for item in items:
        naver_news_list.append(NaverNews(None, **item))
    print(naver_news_list)
   
else:
    print(f"Error Code : {response.status_code}")
# Out:
# [NaverNews(id=None, title='과기정통·산업·중기부, 4320억 규모 AI전환 사업 통합 공고', originallink='https://www.newsis.com/view/NISX20260312_0003545057', link='https://n.news.naver.com/mnews/article/003/0013817590?sid=105', description='과학기술정보통신부, 산업통상자원부, 중소벤처기업부가 산업 <b>인공지능</b>(AI) 전문기업과 제조기업의 AI전환(AX) 사업 참여 환경 개선을 위해 공동 대응한다. 과기정통부와 산업부, 중기부는 올해 주요 AX 사업을 통합... ', pubDate='Thu, 12 Mar 2026 12:00:00 +0900', create_at=None), NaverNews(id=None, title="AI 공포에 주가 40% 폭락…'18년 경력' CEO 물러난다", originallink='https://www.hankyung.com/article/202603138163i', link='https://n.news.naver.com/mnews/article/015/0005261889?sid=105', description="테크 전문매체 디인포메이션은 “<b>인공지능</b>(AI)의 위협에 대응하기 위해 소프트웨어 기업이 경영진 개편에 나선 상징적인 사례”라고 분석했다. 'AI 공포'에 주가 40% 하락 나라옌 CEO는 12일(현지시간) “향후... ", pubDate='Fri, 13 Mar 2026 09:42:00 +0900', create_at=None), NaverNews(id=None, title='[단독]문체부, AI 콘텐츠산업 진흥법 제정 추진...문화<b>인공지능</b>정책과 ...', originallink='https://news.mtn.co.kr/news-detail/2026031310340012270', link='https://news.mtn.co.kr/news-detail/2026031310340012270', description='문화체육관광부가 문화<b>인공지능</b>정책과를 신설하고 <b>인공지능</b> 기반 콘텐츠산업 진흥법(가칭, 이하 AI 콘텐츠산업 진흥법) 제정 준비 작업을 본격화한다. 문체부는 지난해 한국콘텐츠진흥원을 통해 해당 법안 제정을 위한... ', pubDate='Fri, 13 Mar 2026 11:42:00 +0900', create_at=None), NaverNews(id=None, title='이재명 대통령 “약속은 지킵니다”…‘국민주권정부’ 성과 알리기 나...', originallink='https://www.mk.co.kr/article/11987118', link='https://n.news.naver.com/mnews/article/009/0005649646?sid=100', description='이 대통령은 과학기술정보통신부·산업통상자원부·중소벤처기업부가 4230억원대 <b>인공지능</b>(AI) 전환 사업 통합을 공고했다는 소식도 알렸다. 3개 부처는 주요 AI 전환 사업을 통합 공고하고 기업 대상 설명회를 개최할... ', pubDate='Fri, 13 Mar 2026 08:55:00 +0900', create_at=None), NaverNews(id=None, title='한국서부발전, <b>인공지능</b> 활용 5명 체인지메이커 시상', originallink='http://www.fnnews.com/news/202603121624101321', link='https://n.news.naver.com/mnews/article/014/0005490589?sid=101', description='특히 올해 시상식에서는 <b>인공지능</b>(AI) 기술을 기반으로 사회문제 해결에 나선 혁신 사례들이 다수 선정됐다. 디지털 재활 솔루션, 사고 자동 신고 시스템, 급식 복지 플랫폼 등 다양한 분야에서 기술 기반 사회혁신 모델이... ', pubDate='Thu, 12 Mar 2026 16:26:00 +0900', create_at=None), NaverNews(id=None, title='과기정통부,‘<b>인공지능</b> 윤리원칙’ 제정 착수', originallink='https://www.dailian.co.kr/news/view/1620242/?sc=Naver', link='https://n.news.naver.com/mnews/article/119/0003068672?sid=105', description='과학기술정보통신부는 13일 인스파이어 비즈센터 서울에서 ‘<b>인공지능</b> 윤리원칙’과 관련해 전문가 자문단을 발족했다. AI 윤리원칙은 AI가 사회에 미칠 수 있는 긍정적·부정적 영향을 고려해 인간 중심적이고 책임있는... ', pubDate='Fri, 13 Mar 2026 10:02:00 +0900', create_at=None), NaverNews(id=None, title="'<b>인공지능</b> 윤리원칙' 제정에 속도 낸다... &quot;인간중심 AI개발·활용 촉진...", originallink='https://www.ohmynews.com/NWS_Web/View/at_pg.aspx?CNTN_CD=A0003214551&CMPT_CD=P0010&utm_source=naver&utm_medium=newsearch&utm_campaign=naver_news', link='https://n.news.naver.com/mnews/article/047/0002507918?sid=101', description="▲  안전하고 신뢰할 수있는 <b>인공지능</b>(AI) 사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정 ⓒ omilaev on Unsplash 정부가 안전하고 신뢰할 수 있는 <b>인공지능</b>(AI)사회 구현을 위한 '<b>인공지능</b> 윤리원칙' 제정에 본격 착수한다. AI가... ", pubDate='Fri, 13 Mar 2026 10:11:00 +0900', create_at=None), NaverNews(id=None, title='<b>인공지능</b>(AI)·발명과학·토론… 강동구, 미래인재 키운다', originallink='https://biz.heraldcorp.com/article/10693309?ref=naver', link='https://n.news.naver.com/mnews/article/016/0002612874?sid=102', description='4~6월 초등학생 대상 상반기 미래인재육성 프로그램 9개 과정 운영 <b>인공지능</b>(AI) 코딩·자율주행 로봇·짝 토론 등 놀이와 학습 결합해 흥미 높여 포스터 [헤럴드경제=박종일 선임기자]서울 강동구(구청장 이수희)는... ', pubDate='Fri, 13 Mar 2026 07:07:00 +0900', create_at=None), NaverNews(id=None, title='원주, 의료 <b>인공지능</b>·반도체 발전 방안 모색', originallink='https://news.kbs.co.kr/news/pc/view/view.do?ncd=8507431&ref=A', link='https://n.news.naver.com/mnews/article/056/0012141206?sid=101', description='원주시는 어제(12일), 원주미래산업진흥원에서 의료 <b>인공지능</b>과 반도체 산업 육성을 위한 토론회를 개최했습니다. 이 자리에선 의료 분야 <b>인공지능</b>과 반도체 기술 확산 상황을 공유하고, 원주의 첨단 산업 육성 전략을... ', pubDate='Fri, 13 Mar 2026 08:33:00 +0900', create_at=None), NaverNews(id=None, title="과기정통부, '<b>인공지능</b> 윤리원칙' 제정 착수…전문가 자문단 발족", originallink='https://www.etoday.co.kr/news/view/2564836', link='https://www.etoday.co.kr/news/view/25 ...

# %%
import mysql.connector

config = {
    "host":"localhost",
    "port":3306,
    "user":"ohgiraffers",
    "password":"ohgiraffers",
    "database":"menudb"
}

with mysql.connector.connect(**config) as conn:
    with conn.cursor() as cursor:
        try:
            for naver_news in naver_news_list:
                sql = """
                insert into naver_news (title, originallink, link, description, pub_date)
                values(%s,%s,%s,%s,%s)
                """
                cursor.execute(sql,
                               (
                                   naver_news.title, 
                                   naver_news.originallink, 
                                   naver_news.link, 
                                   naver_news.description, 
                                   naver_news.pubDate
                                )
                               )
            conn.commit()
            
        except mysql.connector.Error as e:
            conn.rollback()
            print("DB 오류 :", e)
